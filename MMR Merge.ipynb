# %%
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import csv
import datetime
from bs4 import BeautifulSoup
now = datetime.datetime.now()
# %matplotlib inline

# %%
name = "/Users/Kyle_Staples/Documents/GitHub/IS834/DataScrape/{}.csv"
data1 = pd.read_csv(name.format("03-04-2019_out"))
data2 = pd.read_csv(name.format("All_Data"))

# %%
data1["Player"] = data1["Player"].str.replace('\r','')
data1["Player"] = data1["Player"].str.replace('\n','')

# %% [markdown]
# ## Make data into final form and merge data

# %%
data_final = data1.copy()
data_final.update(data2)
data_final = pd.concat([data1,data2], keys = "Player")
data_final = data_final.sort_values(["Date","Games"], ascending = False ).drop_duplicates(subset = "Player", keep="first", inplace = False)
# Out:
# /anaconda3/envs/Python_37/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Export data into final

# %%
data_final = data_final.sort_values("MMR", ascending = False )
path = '/Users/Kyle_Staples/Documents/GitHub/IS834/DataScrape/All_Data.csv'
data_final.to_csv(path, sep=',', index = False, encoding='utf-8')

# %% [markdown]
# # Extra Test code to be run later

# %%
data_final
# Out:
#                       Date  Games      MMR           Player      Rank  \
# P 0       2019-03-04 13:24    248  8583.54       Sonic.Gary       1.0
#   1       2019-03-04 13:24    106  8253.11  LoliconKing.Tum       2.0
#   2       2019-03-04 13:24    520  8086.02        Epsid.NYX       3.0
#   3       2019-03-04 13:24    246  7944.21          Ron1n_N       4.0
#   4       2019-03-04 13:24     89  7721.07   DarmoNt.Ghetto       5.0
# l 5          2/28/19 14:13    183  7489.48            h1dy.       NaN
# P 5       2019-03-04 13:24    314  7403.88         MaciaJay       6.0
#   6       2019-03-04 13:24    126  7154.84         DK-Rimmy       7.0
#   7       2019-03-04 13:24    196  7060.60          crenKyy       8.0
#   8       2019-03-04 13:24     54  7020.35       Kuihua.MFL       9.0
# l 9          2/28/19 14:13    143  7010.60         LeJordXD       NaN
#   10         2/28/19 14:13    159  6984.68    Xela_Memes...       NaN
# P 9       2019-03-04 13:24    134  6947.28           Vito-.      10.0
#   10      2019-03-04 13:24    301  6913.01          ApexFPS      11.0
#   11      2019-03-04 13:24    241  6912.48         Pengu.G2      12.0
#   12      2019-03-04 13:24    143  6860.04  WeDontTalkAnymo      13.0
# l 16         2/28/19 14:13    143  6774.08    AllbllsMlIlfe       NaN
# P 13      2019-03-04 13:24    326  6715.94       Lazy.Kitsy      14.0
#   14      2019-03-04 13:24    223  6542.78        Funker.PG      15.0
#   15      2019-03-04 13:24    179  6531.56       BeTracingU      16.0
#   16      2019-03-04 13:24    698  6513.90           Spoit-      17.0
#   17      2019-03-04 13:24    317  6496.99    senpapigeo.EG      18.0
# l 21         2/28/19 14:13    103  6490.33   LEGEND.NOJJANG       NaN
# P 18      2019-03-04 13:24    240  6399.56     Peter.Muller      19.0
#   20      2019-03-04 13:24    111  6358.02             J1X.      21.0
#   21      2019-03-04 13:24    176  6356.51  lIllllIlIlIlIll      22.0
#   23      2019-03-04 13:24    182  6325.03     Hotancold.DZ      24.0
#   24      2019-03-04 13:24    297  6315.50      NoCheats...      25.0
#   25      2019-03-04 13:24     70  6282.34   Q_____________      26.0
#   26      2019-03-04 13:24    447  6261.38        Rampy.SSG      27.0
# ...                    ...    ...      ...              ...       ...
#   169904  2019-03-04 13:24    262  -989.37          Sen.to.  169905.0
#   169905  2019-03-04 13:24    224 -1023.58         TheLaw_.  169906.0
#   169906  2019-03-04 13:24    214 -1042.34     ImNotGoodBTW  169907.0
#   169907  2019-03-04 13:24    148 -1046.62       Mr.Friend.  169908.0
#   169908  2019-03-04 13:24    176 -1138.36   Pokemonster929  169909.0
#   169909  2019-03-04 13:24    154 -1156.03             JyCS  169910.0
#   169910  2019-03-04 13:24   2062 -1159.40  Danny.Delicious  169911.0
#   169911  2019-03-04 13:24    398 -1314.17     Stone_Ranger  169912.0
#   169912  2019-03-04 13:24    167 -1318.64       Piggo_Boar  169913.0
#   169913  2019-03-04 13:24    257 -1374.42     ElkkuZombie-  169914.0
#   169914  2019-03-04 13:24    252 -1389.18     Generlc.Name  169915.0
#   169915  2019-03-04 13:24    459 -1403.70  PrcsLeiaDyedLOL  169916.0
#   169916  2019-03-04 13:24    352 -1420.75           TaqiiG  169917.0
#   169918  2019-03-04 13:24     82 -1441.15  reddit_buzzword  169919.0
#   169919  2019-03-04 13:24    125 -1458.66     GoldenChamp.  169920.0
#   169920  2019-03-04 13:24    171 -1463.46  Mother.Russia..  169921.0
#   169921  2019-03-04 13:24    743 -1492.08  YameteOnii-chan  169922.0
#   169923  2019-03-04 13:24     83 -1539.65      ImDeranking  169924.0
#   169924  2019-03-04 13:24    125 -1720.09   FuzeWasHere.eF  169925.0
#   169925  2019-03-04 13:24    381 -1864.93  InjureTeammates  169926.0
#   169926  2019-03-04 13:24    390 -1966.04  ToK1XKMongoIoid  169927.0
#   169927  2019-03-04 13:24    154 -2076.58   SubPewDiePie88  169928.0
#   169928  2019-03-04 13:24    155 -2505.30     thehumantaco  169929.0
#   169929  2019-03-04 13:24    119 -2545.25     RektByUnRank  169930.0
#   169930  2019-03-04 13:24    241 -2606.88        luvz2spwg  169931.0
#   169931  2019-03-04 13:24    360 -2627.63         MrPJSalt  169932.0
#   169932  2019-03-04 13:24    218 -2942.56   copper4arrived  169933.0
#   169933  2019-03-04 13:24    267 -3005.59       youdiedlol  169934.0
#   169934  2019-03-04 13:24    359 -3363.59    ViggoTarasov1  169935.0
#   169935  2019-03-04 13:24    574 -3564.89            Diouz  169936.0
#
#           Unnamed: 0
# P 0              1.0
#   1              2.0
#   2              3.0
#   3              4.0
#   4              5.0
# l 5              NaN
# P 5              6.0
#   6              7.0
#   7              8.0
#   8              9.0
# l 9              NaN
#   10             NaN
# P 9             10.0
#   10            11.0
#   11            12.0
#   12            13.0
# l 16             NaN
# P 13            14.0
#   14            15.0
#   15            16.0
#   16            17.0
#   17            18.0
# l 21             NaN
# P 18            19.0
#   20            21.0
#   21            22.0
#   23            24.0
#   24            25.0
#   25            26.0
#   26            27.0
# ...              ...
#   169904         5.0
#   169905         6.0
#   169906         7.0
#   169907         8.0
#   169908         9.0
#   169909        10.0
#   169910        11.0
#   169911        12.0
#   169912        13.0
#   169913        14.0
#   169914        15.0
#   169915        16.0
#   169916        17.0
#   169918        19.0
#   169919        20.0
#   169920        21.0
#   169921        22.0
#   169923        24.0
#   169924        25.0
#   169925        26.0
#   169926        27.0
#   169927        28.0
#   169928        29.0
#   169929        30.0
#   169930        31.0
#   169931        32.0
#   169932        33.0
#   169933        34.0
#   169934        35.0
#   169935        36.0
#
# [198484 rows x 6 columns]

# %%
data_final = data_final.sort_values("MMR", ascending = False )

# %%
# Out:
#             Date  Games      MMR           Player  Rank  Unnamed: 0
# 0   3/4/19 13:24    248  8583.54       Sonic.Gary   1.0         1.0
# 1   3/4/19 13:24    106  8253.11  LoliconKing.Tum   2.0         2.0
# 2   3/4/19 13:24    520  8086.02        Epsid.NYX   3.0         3.0
# 3   3/4/19 13:24    246  7944.21          Ron1n_N   4.0         4.0
# 4   3/4/19 13:24     89  7721.07   DarmoNt.Ghetto   5.0         5.0
# 5  2/28/19 14:13    183  7489.48            h1dy.   NaN         NaN
# 6   3/4/19 13:24    314  7403.88         MaciaJay   6.0         6.0
# 7   3/4/19 13:24    126  7154.84         DK-Rimmy   7.0         7.0
# 8   3/4/19 13:24    196  7060.60          crenKyy   8.0         8.0
# 9   3/4/19 13:24     54  7020.35       Kuihua.MFL   9.0         9.0
