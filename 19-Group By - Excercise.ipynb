# %% [markdown]
# # Group By and Aggregation Lab Exercise
#
# In this lab, we will reinfornce what we learned with Group By and Aggregation

# %%
## update the latest seaborn (0.9.0)

# %%
## setup our environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

## pandas print columns option
pd.set_option('display.max_columns', 100)

## set the styling for seaborn
sns.set_style("white")

## pandas print columns option (100)


## set the styling for seaborn (white)

# %% [markdown]
# ## About The dataset
#
# - uses a `;` for the delimiter
# - the column names are `'my_datetime', 'event', 'country', 'user_id', 'source', 'topic'`

# %%
# import the group-by-exercise.csv file on the course site as articles
articles = pd.read_csv("/Users/Kyle_Staples/Documents/GitHub/IS834/datasets/group_by-exercise.csv", header = None, sep=";")

articles
# Out:
#                         0     1          2           3        4              5
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
articles.rename(columns = {0:'my_datetime', 1:'event', 2:'country', 3:'user_id', 4:'source', 5:'topic'}, inplace = True)

# %%
# check the types of the datas
articles.dtypes
# Out:
# my_datetime    object
# event          object
# country        object
# user_id         int64
# source         object
# topic          object
# dtype: object

# %%
# if you havent already, made the timestamp column a datetime
articles['timestamp'] = pd.to_datetime(articles["my_datetime"],format = "%Y-%m-%d %H:%M:%S" )

# %% [markdown]
# ## Question 1:  Which source referred the most users?

# %%
articles.groupby("source").count()
# Out:
#          my_datetime  event  country  user_id  topic  timestamp
# source
# AdWords          500    500      500      500    500        500
# Reddit           949    949      949      949    949        949
# SEO              346    346      346      346    346        346

# %% [markdown]
# ## Question 2:  Which topic and source combination had the most users  in country 7

# %%
articles.groupby(["topic","source"]).count()
# Out:
#                        my_datetime  event  country  user_id  timestamp
# topic         source
# Africa        AdWords           22     22       22       22         22
#               Reddit            88     88       88       88         88
#               SEO               15     15       15       15         15
# Asia          AdWords          146    146      146      146        146
#               Reddit           487    487      487      487        487
#               SEO               34     34       34       34         34
# Australia     AdWords           27     27       27       27         27
#               Reddit            72     72       72       72         72
#               SEO               22     22       22       22         22
# Europe        AdWords          187    187      187      187        187
#               Reddit           103    103      103      103        103
#               SEO               32     32       32       32         32
# ...

# %% [markdown]
# ## Question 3:  Create a bar chart for the number of users per hour of the day
#
# Using the full dataset, articles

# %%
# add hour to the dataset
articles['hour'] = pd.to_datetime(articles['timestamp'], format = "%H")

# %%
## rename the user_id column that is the count to total_visitors
articles.rename(columns = {"user_id":"total_visitors"}, inplace = True)

# %%
## make the plot - with Hour of the Day as the x-axis label, Total Visitors as the y label, and Visitors by Hour for the Plot Title
