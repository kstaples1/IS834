# %% [markdown]
# # About
#
# In this lab, we will reinforce the foundations of adding new columns to our dataset and sorting data

# %% [markdown]
# # Step 1:  Setup python for data analysis

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Step 2:  Bring in the dataset

# %%
# load the file and call it fifa
url = "https://public.tableau.com/s/sites/default/files/media/fifa18_clean.csv"
fifa = pd.read_csv(url)

# %%
# explore the basics
fifa.head()
# Out:
#    Wage (€)  Value (€)               Name  Age  \
# 0    565000   95500000  Cristiano Ronaldo   32
# 1    565000  105000000           L. Messi   30
# 2    280000  123000000             Neymar   25
# 3    510000   97000000          L. Suárez   30
# 4    230000   61000000           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# 4  https://cdn.sofifa.org/flags/21.png       92         92
#
#                   Club  ...    RB   RCB   RCM   RDM    RF    RM    RS    RW  \
# 0       Real Madrid CF  ...  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0
# 1         FC Barcelona  ...  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0
# 2  Paris Saint-Germain  ...  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0
# 3         FC Barcelona  ...  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0
# 4     FC Bayern Munich  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     RWB    ST
# 0  66.0  92.0
# 1  62.0  88.0
# 2  64.0  84.0
# 3  68.0  88.0
# 4   NaN   NaN
#
# [5 rows x 74 columns]

# %% [markdown]
# # Step 3: Remove rows

# %%
## remove rows where at least one value is missing
## keep the dataset as fifa
fifa.dropna(inplace = True)

# %%
#fifa.isna().sum()

# %% [markdown]
# # Step 4: Let's keep a few columns
#
# > Save the new dataset as `fifa_final`

# %%
## keep only name, age, Wage (€) , Overall, Agility, Crossing, Curve, Finishing
fifa_final = fifa[["Name", "Age", "Wage (€)" , "Overall", "Agility", "Crossing", "Curve", "Finishing"]].copy()

# %%
fifa_final.head()
# Out:
#                 Name  Age  Wage (€)  Overall  Agility  Crossing  Curve  \
# 0  Cristiano Ronaldo   32    565000       94     89.0      85.0   81.0
# 1           L. Messi   30    565000       93     90.0      77.0   89.0
# 2             Neymar   25    280000       92     96.0      75.0   81.0
# 3          L. Suárez   30    510000       92     86.0      77.0   86.0
# 5     R. Lewandowski   28    355000       91     78.0      62.0   77.0
#
#    Finishing
# 0       94.0
# 1       95.0
# 2       89.0
# 3       94.0
# 5       91.0

# %% [markdown]
# # Step 5:  Calculate 2 columns

# %%
## calculate the difference between overall and finishing
## call the column diff
#fifa_final.isna().sum()

fifa_final['diff'] = fifa_final['Overall'] - fifa_final['Finishing']

# %%
# create a column that calculates the deviation between Age and the average Age
# call this age_diff
fifa_final['age_diff'] = fifa_final['Age'] - fifa_final['Age'].mean()

# %%
fifa_final.head()
# Out:
#                 Name  Age  Wage (€)  Overall  Agility  Crossing  Curve  \
# 0  Cristiano Ronaldo   32    565000       94     89.0      85.0   81.0
# 1           L. Messi   30    565000       93     90.0      77.0   89.0
# 2             Neymar   25    280000       92     96.0      75.0   81.0
# 3          L. Suárez   30    510000       92     86.0      77.0   86.0
# 5     R. Lewandowski   28    355000       91     78.0      62.0   77.0
#
#    Finishing  diff  age_diff
# 0       94.0   0.0  6.996699
# 1       95.0  -2.0  4.996699
# 2       89.0   3.0 -0.003301
# 3       94.0  -2.0  4.996699
# 5       91.0   0.0  2.996699

# %% [markdown]
# # Step 6:  Sort the dataset

# %%
# print out the dataset with the 10 oldest players listed at the top
fifa_final.sort_values('Age',ascending=False, inplace = True)
fifa_final.head(10)
# Out:
#               Name  Age  Wage (€)  Overall  Agility  Crossing  Curve  \
# 7727     K. Wæhler   41      2000       67     33.0      38.0   23.0
# 3309    M. Candelo   40      2000       72     70.0      76.0   76.0
# 3148     T. Simons   40     14000       73     31.0      53.0   46.0
# 13863     M. Brown   40      2000       61     37.0      51.0   45.0
# 2224      B. Nivet   40     16000       74     60.0      69.0   73.0
# 16749   D. Mulcahy   39      1000       55     38.0      52.0   48.0
# 9201      F. Kippe   39      1000       66     46.0      33.0   53.0
# 9184       W. Díaz   39      1000       66     66.0      56.0   27.0
# 853         Hilton   39     18000       78     60.0      60.0   42.0
# 7968   Y. Nakazawa   39      4000       67     37.0      60.0   51.0
#
#        Finishing  diff   age_diff
# 7727        25.0  42.0  15.996699
# 3309        60.0  12.0  14.996699
# 3148        54.0  19.0  14.996699
# 13863       55.0   6.0  14.996699
# 2224        73.0   1.0  14.996699
# 16749       35.0  20.0  13.996699
# 9201        46.0  20.0  13.996699
# 9184        19.0  47.0  13.996699
# 853         45.0  33.0  13.996699
# 7968        40.0  27.0  13.996699

# %% [markdown]
# # Step 7: Sort the dataset 2

# %%
# sort the dataset by Crossing and Curve lowest-> highest, 
# and keep the results in the DataFrame fifa_final
fifa_final.sort_values(['Crossing', 'Curve'],ascending=True, inplace = True)

# %%
# print out the first 7 rows
fifa_final.head(7)
# Out:
#                 Name  Age  Wage (€)  Overall  Agility  Crossing  Curve  \
# 6085    M. Pellizzer   28      2000       69     71.0      11.0   11.0
# 10010     E. Lancini   23      1000       65     56.0      11.0   16.0
# 11205  A. Camigliano   22      1000       64     34.0      11.0   16.0
# 1464      S. De Maio   30     50000       76     49.0      11.0   23.0
# 16710     B. Clayton   19      4000       55     60.0      11.0   32.0
# 5770         F. Poli   28      3000       69     73.0      12.0   11.0
# 8206         M. Bani   23      8000       67     48.0      12.0   13.0
#
#        Finishing  diff  age_diff
# 6085        13.0  56.0  2.996699
# 10010       14.0  51.0 -2.003301
# 11205       13.0  51.0 -3.003301
# 1464        20.0  56.0  4.996699
# 16710       57.0  -2.0 -6.003301
# 5770        13.0  56.0  2.996699
# 8206        12.0  55.0 -2.003301
