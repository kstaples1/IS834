# %%
import numpy as np
import pandas as pd

dd = pd.read_csv('https://public.tableau.com/s/sites/default/files/media/TopBabyNamesbyState.csv')

# %%
dd.shape
# Out:
# (10506, 5)

# %%
dd.isnull().sum()
# Out:
# State         0
# Gender        0
# Year          0
# Top Name      0
# Occurences    0
# dtype: int64

# %%
dd2 = dd.copy()
del dd2["Occurences"]

# %%
m = dd2.loc[dd2["Gender"] == "M"]
f = dd2.loc[dd2["Gender"] == "F"]

# %%
m["Top Name"].value_counts().head(1)
# Out:
# Michael    1404
# Name: Top Name, dtype: int64

# %%
f["Top Name"].value_counts().head(1)
# Out:
# Mary    1935
# Name: Top Name, dtype: int64

# %%
f_1 = f.loc[(f["State"] == "NH")&(f["Year"] >= 1999)]
f_1["Top Name"].value_counts()
# Out:
# Emma      6
# Emily     4
# Sophia    2
# Olivia    2
# Name: Top Name, dtype: int64

# %% [markdown]
# # Part 2

# %% [markdown]
# ## Question 1

# %%
wine = pd.read_csv("https://raw.githubusercontent.com/shri1407/Wine-Quality-Dataset/master/winequality-white.csv", delimiter=";")

# %%
wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# ## Question 2

# %%
wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Question 3

# %%
wine["alcohol"].mean()
# Out:
# 10.514267047774602

# %% [markdown]
# ## Question 4

# %%
wine.std()
# Out:
# fixed acidity            0.843868
# volatile acidity         0.100795
# citric acid              0.121020
# residual sugar           5.072058
# chlorides                0.021848
# free sulfur dioxide     17.007137
# total sulfur dioxide    42.498065
# density                  0.002991
# pH                       0.151001
# sulphates                0.114126
# alcohol                  1.230621
# quality                  0.885639
# dtype: float64

# %% [markdown]
# ## Question 5

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ## Question 6

# %%
wine2 = wine.loc[(wine["citric acid"] >0.334192) |(wine["density"]<=0.996100) ]

# %%
wine.shape[0] - wine2.shape[0]
# Out:
# 614

# %%
wine2.shape[0]
# Out:
# 4284

# %% [markdown]
# ## Question 7

# %%
wine2.quality.value_counts()
# Out:
# 6    1922
# 5    1213
# 7     819
# 8     161
# 4     146
# 3      18
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# # Problem 3

# %% [markdown]
# ## Question 1

# %%
ab = pd.read_excel('https://public.tableau.com/s/sites/default/files/media/airbnb.xlsx', sheet_name = 'AirBnB_NYC')

# %%
ab.shape
# Out:
# (30478, 13)

# %% [markdown]
# ## Question 2

# %%
ab.notnull().sum()
# Out:
# Host Id                       30478
# Host Since                    30475
# Name                          30478
# Neighbourhood                 30478
# Property Type                 30475
# Review Scores Rating (bin)    22155
# Room Type                     30478
# Zipcode                       30344
# Beds                          30393
# Number of Records             30478
# Number Of Reviews             30478
# Price                         30478
# Review Scores Rating          22155
# dtype: int64

# %% [markdown]
# ## Question 3

# %%
ab2 = ab.copy()
del ab2["Number of Records"]

# %%
# Out:
# 0

# %%
# Out:
# 0

# %% [markdown]
# ## Question 4

# %%
ab.Beds.fillna(ab.Beds.mean(), inplace = True)

# %%
ab.Beds.mean()
# Out:
# 1.5300891652683184

# %% [markdown]
# ## Question 5

# %%
beds4 = ab.loc[ab["Beds"] >=4]

# %%
beds4.count()
# Out:
# Host Id                       1366
# Host Since                    1366
# Name                          1366
# Neighbourhood                 1366
# Property Type                 1366
# Review Scores Rating (bin)    1069
# Room Type                     1366
# Zipcode                       1356
# Beds                          1366
# Number of Records             1366
# Number Of Reviews             1366
# Price                         1366
# Review Scores Rating          1069
# dtype: int64

# %% [markdown]
# ## Question 6

# %%
beds4.Zipcode.isna().sum()
# Out:
# 10

# %% [markdown]
# ## Question 7

# %%
beds4.dropna()
# Out:
#         Host Id Host Since                                 Name  \
# 28         3867 2008-10-29    3 bedroom apartment in Chinatown!
# 43         5926 2009-01-02        Beautiful Apt with Park Views
# 101        8730 2009-02-27                Comfort & Convenience
# 171       21823 2009-06-16           Soaring Bushwick 3 Bedroom
# 174       22486 2009-06-20          CBG Williamsburg  loft room
# 176       22486 2009-06-20        CBG CtyBeGoodHelpsHaiti#1:1-4
# 191       24222 2009-07-02       3BR, 1.5 BA EV apt w/ backyard
# 193       25183 2009-07-10                 MAISON DES SIRENES 3
# 194       25183 2009-07-10         MAISON DES SIRENES1,book NOW
# 241       32330 2009-08-18   East Vill Garden duplex apt-slps 7
# 242       32330 2009-08-18  HUGE-3 bedroom-ENTIRE FLR -slps 6+2
# 243       32330 2009-08-18  LARGE-3 bedroom -EAST VILL-slps 6+3
# 283       38513 2009-09-14     Spacious Modern  2 Bedroom Suite
# 292       40275 2009-09-21   Spacious Lofty 2BD in Clinton Hill
# ...

# %%
beds4.isna().sum()
# Out:
# Host Id                         0
# Host Since                      0
# Name                            0
# Neighbourhood                   0
# Property Type                   0
# Review Scores Rating (bin)    297
# Room Type                       0
# Zipcode                        10
# Beds                            0
# Number of Records               0
# Number Of Reviews               0
# Price                           0
# Review Scores Rating          297
# dtype: int64
