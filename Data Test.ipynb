# %%
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import csv

# %matplotlib inline

# %%
data = requests.get("https://r6tab.com/api/leaderboards.php?sortplatform=uplay&sortregion=p_currentmmr").json()
#data = pd.read_json("https://r6tab.com/api/leaderboards.php?sortplatform=uplay&sortregion=p_currentmmr", lines=True)

# %%
dd = pd.DataFrame.from_dict(data)

# %%
x = dd["p_currentmmr"]
x = x.values
x = x.astype(np.int)

# %%
bins = [0,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2700,2900,3100,3300,3700,4100,4500]
plt.hist(np.clip(x, bins[0], bins[-1]), bins = bins )
#plt.hist(x)
plt.show()

# %%
from bs4 import BeautifulSoup
#scrape elements
COLUMNS = ['Rank', 'Player', 'MMR', 'Games']
dataframes = []
i = 1
url = "https://r6.tracker.network/leaderboards/pvp-season/pc/Mmr?page={}&region=-1&season=12"
#1725
while(i<3):
    try:
        response = requests.get(url.format(i))
        soup = BeautifulSoup(response.content, "html.parser")
        table = soup.find("table") # Find the "table" tag in the page
        rows = table.find_all("tr") # Find all the "tr" tags in the table
        cy_data = []
        for row in rows:
            cells = row.find_all("td") #  Find all the "td" tags in each row
            cells = cells[0:4] # Select the correct columns
            cy_data.append([cell.text for cell in cells]) # For each "td" tag, get the text inside it

        dataframes.append(pd.DataFrame(cy_data, columns=COLUMNS).drop(0, axis=0))
        i= i+1
        print(i)
    except:
        break
final = pd.concat(dataframes)
print("finished")
# Out:
# 2
# 3
# finished

# %%
#final = final.set_index('Rank')
final2.tail()
# Out:
#        Rank                 Player     MMR Games
# 96   166396          \nlrmingo\n\n  531.60    24
# 97   166397  \nFree_Jahlestine\n\n  530.66    31
# 98   166398        \ntahribatp\n\n  530.50    69
# 99   166399    \nMoiado.Liquid\n\n  529.93    30
# 100  166400   \njustengineer10\n\n  528.70   105

# %%
final2 = final.copy()
final2["MMR"] = final2["MMR"].str.replace(',','')
x = final2["MMR"]
x = x.values
x = x.astype(np.double)
bins = [0,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2700,2900,3100,3300,3700,4100,4500]
plt.hist(np.clip(x, 0, 4500), bins = bins, rwidth = 0.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-479076a26024> in <module>
#       1 final2 = final.copy()
#       2 final2["MMR"] = final2["MMR"].str.replace(',','')
# ----> 3 final2["Player"] = final2["Player"].rstrip('/n')
#       4 x = final2["MMR"]
#       5 x = x.values
#
# /anaconda3/envs/Python_37/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'rstrip'

# %%
final2["Player"] = final2["Player"].str.replace('\n','')

# %%
final2["Player"].head()
# Out:
# 1         Sonic.Gary
# 2    LoliconKing.Tum
# 3          Epsid.NYX
# 4            Ron1n_N
# 5     DarmoNt.Ghetto
# Name: Player, dtype: object

# %%
final2.to_csv('/Users/Kyle_Staples/Desktop/out2.csv', sep=',', encoding='utf-8')

# %%
#final2.set_index("Rank")

# %%
final2.loc[final2.Player.duplicated()].sort_values('Player')
# Out:
#       Rank           Player      MMR Games
# 57  131656   A-Alpha_Wolfie  2139.17    13
# 97   75197     A-Gunner.RPR  2669.08     3
# 22  154122          A-Lemao  1690.66   341
# 12  119512          A-Y-D-A  2275.81     4
# 73  119373         A-founds  2277.18     4
# 21   57921           A-sin.  2846.78    19
# 12  162512          A.Basic  1246.95   151
# 15  147615       A.I.M.polo  1868.27    13
# 60   58060          A.Iroha  2845.19     8
# 22  110522        A.Navalny  2368.08     1
# 16   78816             A.RJ  2635.90     1
# 11   90611       A.Wild.Muk  2533.78   241
# 5    33905    A.Winchester.  3156.87    21
# 78  153678  A.cow.from.IRAQ  1704.55    12
# 66  122566         A021rmin  2248.23    23
# 23  160523         A021rmin  1397.52   820
# 64   42764          A1dSpam  3029.18     6
# 21   39921           A1kyan  3070.43    27
# 50   67150          A1tair8  2750.10     8
# 68   80268    A26.LambOfGod  2627.84     3
# 71  145571             A4-.  1912.37    84
# 91  105891         A51TN.BC  2395.29     7
# 67   80767           A7.M4h  2624.91     9
# 57  110256        A9.erfy77  2369.05     1
# 14  111114        A9.erfy77  2365.64     5
# 6    93506        ABUSERkQ8  2510.32     2
# 6    65006        ABU_SHEBA  2768.25    12
# 14   85814  ABitSmarter.exe  2583.02    13
# 17   65817          ACE.FTH  2761.27     4
# 37  106037      ACEing_So1o  2393.91     3
# ..     ...              ...      ...   ...
# 79   34379       zTrMvToko.  3149.25   177
# 98  101698            zVc-.  2440.19     6
# 37  112737       zVenom.NHj  2354.46     3
# 2   122902     zZMaV3RiCkZz  2245.80    20
# 29  101729         zZykubbe  2439.81    98
# 98   25198           zak.am  3310.16    15
# 81  108481          zayts07  2376.41     1
# 84  158984     zeler_lim594  1489.99    32
# 61  110961     zeler_lim594  2366.34     1
# 20   67720         zerd.ESR  2744.99   229
# 92   11992          zetton_  3646.86    88
# 27  139727      zhika_zhyar  2020.34    44
# 27   74927           ziWino  2671.97    14
# 66   74266         zibits.-  2679.26    10
# 35    5435          zilchy.  4055.38    83
# 45   86345            zips.  2577.71     3
# 34   18934             zkk.  3429.81    16
# 48  164148         zombozog  1075.45   117
# 91   55391         zoroboy.  2874.07   140
# 67   47067      zphyr.JOk3R  2974.33   323
# 30   90030    zphyr.Videira  2539.44    47
# 23   77323  zphyr.icebullet  2647.72     9
# 72  166272      zuizui.Rolm   592.85    81
# 49  141649      zuizui.Rolm  1989.84    10
# 87   44087         zuluboer  3011.84    31
# 87   91787        zumiko_V4  2523.35     2
# 58   64058            zxyy.  2777.75    34
# 4    18204            zyph.  3446.96   103
# 3   110803        zz.choppa  2367.06     1
# 73  125473    zzFreshPrince  2223.41   155
#
# [11596 rows x 4 columns]
